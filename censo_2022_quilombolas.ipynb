# %% [markdown]
# <link rel="image_src" href="https://imagens.ebc.com.br/z-UBWGsQozSGavq4vkJ6QCT9yXE=/1600x800/https://agenciabrasil.ebc.com.br/sites/default/files/thumbnails/image/_povos_tradicionais._quilombolas_de_goias_go11092000299_0.jpg?itok=mNrsdAhq">

# %% [markdown]
#  # CENSO 2022 - DADOS INICIAIS -POPULAÇÃO QUILOMBOLA

# %% [markdown]
# ## Dados coletados no site do IBGE

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# <image href="https://imagens.ebc.com.br/z-UBWGsQozSGavq4vkJ6QCT9yXE=/1600x800/https://agenciabrasil.ebc.com.br/sites/default/files/thumbnails/image/_povos_tradicionais._quilombolas_de_goias_go11092000299_0.jpg?itok=mNrsdAhq">

# %%
base_data = pd.read_excel('tabela_01_populacao_quilombola_BR_GR.xlsx',skiprows=7,skipfooter=2)
base_data.rename(columns={'Unnamed: 0': 'Regiões'}, inplace=True)

base_data
# Out:
#     Regiões  Pessoas quilombolas (Pessoas)  \
# 0    Brasil                        1327802
# 1     Norte                         166069
# 2  Nordeste                         905415
# 3   Sudeste                         182305
# 4       Sul                          29056
#
#    Pessoas quilombolas - percentual do total geral (%)  \
# 0                                                100
# 1                                                100
# 2                                                100
# 3                                                100
# 4                                                100
#
#    População residente (Pessoas)  \
# 0                      203062512
# 1                       17349619
# 2                       54644582
# 3                       84847187
# 4                       29933315
#
#    Percentual de pessoas quilombolas no total de população residente (%)  \
# 0                                               0.65
# ...

# %%
base_data.set_index('Regiões')
base_data.columns
# Out:
# Index(['Regiões', 'Pessoas quilombolas (Pessoas)',
#        'Pessoas quilombolas - percentual do total geral (%)',
#        'População residente (Pessoas)',
#        'Percentual de pessoas quilombolas no total de população residente (%)',
#        'Pessoas quilombolas (Pessoas).1',
#        'Pessoas quilombolas - percentual do total geral (%).1',
#        'População residente (Pessoas).1',
#        'Percentual de pessoas quilombolas no total de população residente (%).1',
#        'Pessoas quilombolas (Pessoas).2',
#        'Pessoas quilombolas - percentual do total geral (%).2',
#        'População residente (Pessoas).2',
#        'Percentual de pessoas quilombolas no total de população residente (%).2'],
#       dtype='object')

# %%
base_data[['Pessoas quilombolas (Pessoas)',
       'Pessoas quilombolas - percentual do total geral (%)',
       'População residente (Pessoas)',
       'Percentual de pessoas quilombolas no total de população residente (%)',
       'Pessoas quilombolas (Pessoas).1',
       'Pessoas quilombolas - percentual do total geral (%).1',
       'População residente (Pessoas).1',
       'Percentual de pessoas quilombolas no total de população residente (%).1',
       'Pessoas quilombolas (Pessoas).2',
       'Pessoas quilombolas - percentual do total geral (%).2',
       'População residente (Pessoas).2',
       'Percentual de pessoas quilombolas no total de população residente (%).2']].mean()
# Out:
# Pessoas quilombolas (Pessoas)                                                522,129.40
# Pessoas quilombolas - percentual do total geral (%)                              100.00
# População residente (Pessoas)                                             77,967,443.00
# Percentual de pessoas quilombolas no total de população residente (%)              0.72
# Pessoas quilombolas (Pessoas).1                                               65,439.20
# Pessoas quilombolas - percentual do total geral (%).1                             15.02
# População residente (Pessoas).1                                               79,395.00
# Percentual de pessoas quilombolas no total de população residente (%).1           77.67
# Pessoas quilombolas (Pessoas).2                                              456,690.20
# Pessoas quilombolas - percentual do total geral (%).2                             84.98
# População residente (Pessoas).2                                           77,888,048.00
# ...

# %%
base_data.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
